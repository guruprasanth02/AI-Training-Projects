# %%
# !pip install pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\guruprasanth\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Importing necessary Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %% [markdown]
# Load data

# %%
df = pd.read_csv('D:\AI Training Projects\Project 02\spam mail.csv')
df.head()
# Out:
#   Category                                           Messages
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Categorize the dataset

# %%
df["Category"] = df["Category"].map({"spam":1, "ham":0})
df.head()
# Out:
#    Category                                           Messages
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Check columns

# %%
print(df.columns)
# Out:
# Index(['Category', 'Messages'], dtype='object')

# %% [markdown]
# Extract Simple numeric features

# %%
df["length"] = df["Messages"].apply(len)
df["digits"] = df["Messages"].apply(lambda x: sum(c.isdigit() for c in x))
df["special"] = df["Messages"].apply(lambda x: sum(not c.isalnum() and not c.isspace() for c in x))

# %%
class_ = ["ham", "spam"]

# %% [markdown]
# Label Encoding (Ham=0, spam=1)

# %%
label_encoder = LabelEncoder()
df["label_encoded"] = label_encoder.fit_transform(df["Category"])

# %% [markdown]
# Keep original messages for printing later

# %%
X_text = df["Messages"].copy()
X = df[["length", "digits", "special"]]
y = df["Category"]

# %%
X
# Out:
#       length  digits  special
# 0        111       0        9
# 1         29       0        6
# 2        155      25        6
# 3         49       0        6
# 4         61       0        2
# ...      ...     ...      ...
# 5567     161      21        9
# 5568      37       0        2
# 5569      57       0        7
# 5570     125       0        1
# 5571      26       0        1
#
# [5572 rows x 3 columns]

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, y_train, y_test, X_train_text, X_test_text = train_test_split(
    X, y, X_text, test_size=0.20, random_state=42
)

# %% [markdown]
# Scaling the features

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Train Logistic regression model

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
sample_email = X_test_scaled
sample_email
# Out:
# array([[ 1.23186777,  0.41854406, -0.48501146],
#        [ 2.44262424, -0.37797638, -0.0653054 ],
#        [ 0.36704172,  2.33019313, -0.27515843],
#        ...,
#        [-0.29022608, -0.37797638,  0.35440066],
#        [-0.99938343, -0.37797638, -0.48501146],
#        [-0.09996434,  1.05576042, -0.27515843]])

# %% [markdown]
# Predict Sigmoid probabilities for all test samples

# %%
probabilities = model.predict_proba(sample_email)
probabilities
# Out:
# c:\Users\GuruPrasanth\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[0.985643  , 0.014357  ],
#        [0.99207063, 0.00792937],
#        [0.95307711, 0.04692289],
#        ...,
#        [0.99303713, 0.00696287],
#        [0.99180245, 0.00819755],
#        [0.97954468, 0.02045532]])

# %% [markdown]
# User Input Email prediction using trained model

# %%
n_samples = 5

# Random indexes from y_test
random_idx = np.random.choice(len(y_test), n_samples, replace=False)

print(f"Categories: {class_}")
print("="*60)

for i, idx  in enumerate(random_idx):
    # If using softmax (2 outputs: ham, spam)
    prob = probabilities[idx]
    spam_prob = prob[1]   # P(y=1) = Spam

    prediction = "Spam" if spam_probability > 0.5 else "Ham"

    email_text = X_test_text.iloc[idx]   # X_test_text = original test messages
    
user_email = input("\nEnter an email text to classify: ")
user_email = str(user_email)

# Extract same numeric features used in training
user_length = len(user_email)
user_digits = sum(c.isdigit() for c in user_email)
user_special = sum(not c.isalnum() and not c.isspace() for c in user_email)

# Create a single-row dataframe for prediction
user_features = pd.DataFrame([{
    "length": user_length,
    "digits": user_digits,
    "special": user_special
}])

# Predict probability
user_prob = model.predict_proba(user_features)[0][1]   # P(spam)
user_pred = "Spam" if user_prob > 0.5 else "Ham"

print("\n--- USER EMAIL PREDICTION ---")
print(f"Email Entered:\n{user_email}\n")
print(f"Sigmoid Output = {user_prob:.4f} ({user_prob*100:.1f}%)")
print(f"Final Prediction: {user_pred}")
print("------------------------------------")
# Out:
# Categories: ['ham', 'spam']
# ============================================================
#
# --- USER EMAIL PREDICTION ---
# Email Entered:
# As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a Ã¥Â£1500 Bonus Prize, call 09066364589
#
# Sigmoid Output = 0.9989 (99.9%)
# Final Prediction: Spam
# ------------------------------------
